# %%
n = input('Inter a game')

L = len(n)


def len2(type):
    
     x = [x for x in type]
     
     digit =x[1].isdigit() 
     
     if x[0] in x[0].lower() and L < 3 and digit == True :
         
        print('yes')
     
     else:
       print('no')

# %%
# n = input('Inter a game')
# L = len(n)

# def len3(type):
      
#       x = [x for x in type]
      
#       digit =x[1].isdigit() 
#       digit2 =x[2].isdigit() 
  

#       if x[0] in x[0].lower() and L < 4  and x[-1] == '#' or x[-1]=='+'and digit == True:
       
#         print('yes1')
        
#       elif x[0] in x[0].upper() and L < 4  and digit2 == True  and x[1] in x[1].lower():
            
#         print('True')      
        
#       elif x[0]  in x[0] =='O' and x[1]=='-' and x[2]=='O':
#         print('yes2')
        
#       else:
#         print('no')  
               
  




# len3(n)

# %%
n = input('Inter a game')
L = len(n)

def len4(type):
      
      x = [x for x in type]
      
      digit =x[1].isdigit() 
      digit2 =x[2].isdigit() 
      digit2 =x[3].isdigit() 
  

      if x[0] in x[0].upper() and x[1] in x[1].lower() and L < 5  and x[-1] == '#' or x[-1]=='+'and digit2 == True:
       
        print('yes1')
        
      elif x[0] in x[0].upper() and L < 4  and digit2 == True  and x[1] in x[1].lower():
            
        print('True')      
        
      elif x[0]  in x[0] =='O' and x[1]=='-' and x[2]=='O':
        print('yes2')
        
      else:
        print('no')  
               
  



len4(n)

# %%
def IsFunction (type):
    
    if type==True:
         
       return len2(n)
    
    elif type==True:
        
      return  len3(n)
     
    elif type == True:
        
        return len4(n) 
    
    else:
        print('Invlid') 
 
IsFunction(n)

# %%
def Move_lan2(s):
    
    
    if not ord(s[0])>= ord('a') and ord(s[0])<= ord('z'):
          invild = False                   
    elif not ord(s[1])>= ord('0') and ord(s[1])<= ord('9'):
          invild = False
    return False       




def Move_len3(s):
    
    if Move_lan2(s[1:]) and s[2:] in ['+',"#"]:
        return True
    
    elif ord(s[0])>= ord('A') and ord(s[0])<= ord('Z') and Move_lan2(s[1:]):
        return True
    
    elif s == 'O-O':
        return True 
    
    return False


    
def Move_lan4 ():
    
    if ord(s[0])>= ord('A') and ord(s[0])<= ord('Z') and Move_lan2(s[2:]) and s[3]==['+',"#"] :
        return True
    
    
    elif ord(s[0])>= ord('a') and ord(s[0])<= ord('z') and x[1] =='x' and Move_lan2 (s[2:]):
        return True
    
    
    elif ord(s[0])>= ord('A') and ord(s[0])<= ord('Z') and ord(s[1])>= ord('a') and ord(s[1])<= ord('z') and Move_lan2(s[2:]):
        
        return True
    
    elif ord(s[0])>= ord('A') and ord(s[0])<= ord('Z') and ord(s[1])>= ord('1') and ord(s[1])<= ord('9') and Move_lan2(s[2:]): 
        
        return True
    
    return False

# %%
def  my_function(s):
    
    if len(s)==2:
        return Move_lan2(s)
    
    elif len(s)==3:
        return Move_len3(s)
    
    # elif len(s)==4:
    #     return Move_lan4(s)
    
    else:
         return True

# %%
def chakehas(x):
    Counter = 0
    for i in x:
        i[-1] =='#'
        Counter += 1
        print(Counter)    
    return Counter

# %%
invild = False

x = ['e4' ,'e5', 'Qf3', 'cxd7' ,'Qa4+' ,'Nbd7' ,'O-O', 'R1b3', 'Na4#']

for s in x:
 if len(s) > 4:
    Invild = True

for s in x:
    print(s)
    if my_function(s)==False:
        Invild = True
        
        
if x[-1][ -1] !='#':
    
    Invild = True
    
if chakehas(x) >1:
    Invild =True
        
if Invild:
    print('The game is invild') 
else:
    print('The game is vlid')
# Out:
# e4
# e5
# Qf3
# cxd7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b7e064454697> in <module>
#       9 for s in x:
#      10     print(s)
# ---> 11     if my_function(s)==False:
#      12         Invild = True
#      13
#
# <ipython-input-9-a7ed1ff0a190> in my_function(s)
#       8
#       9     elif len(s)==4:
# ---> 10         return Move_lan4(s)
#      11
#      12     else:
#
# TypeError: Move_lan4() takes 0 positional arguments but 1 was given
